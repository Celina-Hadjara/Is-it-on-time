# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
dataTest = pd.read_csv("dataFlight.csv", sep=',')

data=(dataTest[dataTest['Year']>2002])

data[['SecurityDelay','CarrierDelay','WeatherDelay','NASDelay','LateAircraftDelay','DepDelayMinutes']] = data[['SecurityDelay','CarrierDelay','WeatherDelay','NASDelay','LateAircraftDelay','DepDelayMinutes']].fillna(value=0)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data.shape

df = data.loc[:, ['Year','Quarter','Month', 'DayofMonth', 'DayOfWeek', 'FlightDate', 'Reporting_Airline', 'Flight_Number_Reporting_Airline',
'Origin', 'OriginCityName', 'OriginState', 'OriginStateName', 'Dest', 'DestCityName', 'DestState', 'DestStateName', 'DestWac',
'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'CRSArrTime', 'ArrTime', 'ArrDelayMinutes', 'Cancelled',  
'Diverted', 'Flights', 'Distance', 'DistanceGroup', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']]
df.head()

df.to_csv('DataFlightFinal.csv', index=False)

# %%
# Out:
#     Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 4   2006        1      1          15          7  2006-01-15                US
# 7   2019        2      6          11          2  2019-06-11                9E
# 9   2018        1      2           8          4  2018-02-08                WN
# 23  2020        1      3          24          2  2020-03-24                YV
# 24  2010        3      8          20          5  2010-08-20                OO
#
#     Flight_Number_Reporting_Airline Origin OriginCityName OriginState  \
# 4                               465    EWR     Newark, NJ          NJ
# 7                              3459    ATL    Atlanta, GA          GA
# 9                              5932    MDW    Chicago, IL          IL
# 23                             5825    PHX    Phoenix, AZ          AZ
# 24                             6582    BUR    Burbank, CA          CA
#
#    OriginStateName Dest       DestCityName DestState   DestStateName  DestWac  \
# 4       New Jersey  CLT      Charlotte, NC        NC  North Carolina       36
# 7          Georgia  CAE       Columbia, SC        SC  South Carolina       37
# 9         Illinois  DAL         Dallas, TX        TX           Texas       74
# 23         Arizona  LGB     Long Beach, CA        CA      California       91
# 24      California  SFO  San Francisco, CA        CA      California       91
#
#     CRSDepTime  DepTime  DepDelayMinutes  TaxiOut  CRSArrTime  ArrTime  \
# 4         1820   1911.0             51.0     19.0        2026   2058.0
# 7         1950   2331.0            221.0     19.0        2057     31.0
# 9         2030   2046.0             16.0     34.0        2250   2319.0
# 23        1858   1950.0             52.0      9.0        2021   2105.0
# 24        1342   1352.0             10.0     20.0        1453   1510.0
#
#     ArrDelayMinutes  Cancelled  Diverted  Flights  Distance  DistanceGroup  \
# 4              32.0        0.0       0.0      1.0     529.0              3
# 7             214.0        0.0       0.0      1.0     192.0              1
# 9              29.0        0.0       0.0      1.0     793.0              4
# 23             44.0        0.0       0.0      1.0     355.0              2
# 24             17.0        0.0       0.0      1.0     326.0              2
#
#     CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 4            0.0           0.0       0.0            0.0               32.0
# 7            0.0           0.0       0.0            0.0              214.0
# 9            0.0           0.0      13.0            0.0               16.0
# 23          44.0           0.0       0.0            0.0                0.0
# 24           9.0           0.0       7.0            0.0                1.0

# %%
df.to_csv('DataFlightFinal.csv', index=False)

# %%
dataTest["Reporting_Airline"].unique().shape
# Out:
# (33,)

# %%
# Convert the date column to datetime format
df['FlightDate'] = pd.to_datetime(df['FlightDate'], format='%y-%m-%d')

# Sort the DataFrame by date
df = df.sort_values('FlightDate', ascending=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
column_list = list(dataTest.columns)

# print the list of column names
print(len(column_list))
df_filtered = dataTest[dataTest["ArrDelayMinutes"] == 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\naitmaam\Desktop\test.ipynb Cell 8 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/naitmaam/Desktop/test.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Convert the date column to datetime format
# ----> <a href='vscode-notebook-cell:/c%3A/Users/naitmaam/Desktop/test.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> df['FlightDate'] = pd.to_datetime(df['FlightDate'], format='%y-%m-%d')
#       <a href='vscode-notebook-cell:/c%3A/Users/naitmaam/Desktop/test.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> # Sort the DataFrame by date
#       <a href='vscode-notebook-cell:/c%3A/Users/naitmaam/Desktop/test.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> df = df.sort_values('FlightDate', ascending=True)
#
# File c:\Python310\lib\site-packages\pandas\core\tools\datetimes.py:1069, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1067         result = arg.map(cache_array)
#    1068     else:
# -> 1069         values = convert_listlike(arg._values, format)
#    1070         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1071 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Python310\lib\site-packages\pandas\core\tools\datetimes.py:431, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     428         format = None
#     430 if format is not None:
# --> 431     res = _to_datetime_with_format(
#     432         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     433     )
#     434     if res is not None:
#     435         return res
#
# File c:\Python310\lib\site-packages\pandas\core\tools\datetimes.py:539, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     536         return _box_as_indexlike(result, utc=utc, name=name)
#     538 # fallback
# --> 539 res = _array_strptime_with_fallback(
#     540     arg, name, tz, fmt, exact, errors, infer_datetime_format
#     541 )
#     542 return res
#
# File c:\Python310\lib\site-packages\pandas\core\tools\datetimes.py:474, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     471 utc = tz == "utc"
#     473 try:
# --> 474     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     475 except OutOfBoundsDatetime:
#     476     if errors == "raise":
#
# File c:\Python310\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2006-01-15' does not match format '%y-%m-%d' (match)
